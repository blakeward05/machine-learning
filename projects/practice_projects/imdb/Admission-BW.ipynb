# %%
import pandas as pd
data = pd.read_csv('student_data.csv')
data #this command prints out a pandas data frame in a formatted with columns and rows, doesn't work if a statement comes after
data[data.isnull().any(1)]
data.iloc[187]
#type(data)
# Out:
# admit    0.0
# gre      NaN
# gpa      NaN
# rank     2.0
# Name: 187, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
def plot_points(data):
    X = np.array(data[['gre','gpa']])
    y = np.array(data['admit'])
    admitted = X[np.argwhere(y==1)]
    rejected = X[np.argwhere(y==0)]
    plt.scatter([s[0][0] for s in rejected], [s[0][1] for s in rejected], s=25, color = 'red', edgecolor = 'k')
    plt.scatter([s[0][0] for s in admitted], [s[0][1] for s in admitted], s=25, color = 'cyan', edgecolor = 'k')
    plt.xlabel("gre")
    plt.ylabel("gpa")

plot_points(data)
plt.show()

# %%
data_rank1 = data[data["rank"]==1]
data_rank2 = data[data["rank"]==2]
data_rank3 = data[data["rank"]==3]
data_rank4 = data[data["rank"]==4]
plot_points(data_rank1)
plt.title("Rank 1")
plt.show()
plot_points(data_rank2)
plt.title("Rank 2")
plt.show()
plot_points(data_rank3)
plt.title("Rank 3")
plt.show()
plot_points(data_rank4)
plt.title("Rank 4")
plt.show()

# %%
#import keras
#from keras.utils import np_utils

#REMOVE NAS
data = data.fillna(0)
data.iloc[187]

processed_data = pd.get_dummies(data,columns=['rank'])
processed_data["gre"] = processed_data["gre"]/800
processed_data["gpa"] = processed_data["gpa"]/4

X = np.array(processed_data)[:,1:]
y = np.array(processed_data)[:0]
# Out:
# array([[ 0.475 ,  0.9025,  0.    , ...,  0.    ,  1.    ,  0.    ],
#        [ 0.825 ,  0.9175,  0.    , ...,  0.    ,  1.    ,  0.    ],
#        [ 1.    ,  1.    ,  0.    , ...,  0.    ,  0.    ,  0.    ],
#        ...,
#        [ 0.575 ,  0.6575,  0.    , ...,  1.    ,  0.    ,  0.    ],
#        [ 0.875 ,  0.9125,  0.    , ...,  1.    ,  0.    ,  0.    ],
#        [ 0.75  ,  0.9725,  0.    , ...,  0.    ,  1.    ,  0.    ]])
